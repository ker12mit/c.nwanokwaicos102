# %% [markdown]
# START
# INPUT number of items
# INPUT price of items
# CALCULATE total cost
# PAY
# COLLECT receipt
# GO for security check
# IF security check is good
#     LEAVE
# ELSE go back and pay

# %% [markdown]
# ![flowchart1.jpg](attachment:747b8ff5-552e-4e18-b481-d2de6a6f018b.jpg)

# %% [markdown]
# ![flowchart2.jpg](attachment:d73fb875-4bd7-43aa-a860-ab3af9cfc938.jpg)
